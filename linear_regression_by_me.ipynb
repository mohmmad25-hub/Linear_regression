# %% [markdown]
# <a href="https://colab.research.google.com/github/mohmmad25-hub/linear_regression/blob/main/linear_regression_by_me.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/house_prices_100.csv')
df.head()
# Out:
#         Size       Price
# 0  50.000000  275.130019
# 1  51.010101  292.060593
# 2  52.020202  277.403937
# 3  53.030303  309.777449
# 4  54.040404  291.357684

# %%
x = df.drop('Price', axis=1)
y = df['Price']

# %%
plt.scatter(x, y)
plt.xlabel('House Size')
plt.ylabel('price')
plt.grid(True)
plt.show()

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
Alpha = model.intercept_
Beta = model.coef_

print(f'y = {Alpha} + {Beta}X')
# Out:
# y = 155.18316422397433 + [2.43605662]X

# %%
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.scatter(x_train, y_train, label='Training Data')
plt.subplot(1, 2, 2)
plt.scatter(x_test, y_test, label='Testing Data')

# %%
mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)

mae_train = mean_absolute_error(y_train, y_pred_train)
mae_test = mean_absolute_error(y_test, y_pred_test)

# %%
performance = pd.DataFrame({
    'metrics': ['MSE', 'MAE', 'MSE', 'MAE'],
    'Datatype': ['Train', 'Train', 'Test', 'Test'],
    'Values': [mse_train, mae_train, mse_test, mae_test]
})
performance.T
# Out:
#                   0         1           2          3
# metrics         MSE       MAE         MSE        MAE
# Datatype      Train     Train        Test       Test
# Values    97.232062  8.006047  214.758428  11.049659
